# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
from plot_utils import plot_source_likelihood_surface as plot_surface

# %%
graph_type = 'dist_mean'
dirname = 'source-likelihood'
param = '2-6'
if graph_type.startswith('dist'):
    angle = (10, 45)
else:
    angle = (15, 210)

# %%
fig, ax = plot_surface('er', param, graph_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface('barabasi', param, graph_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_surface('kr-hier', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90d07ed4e0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90d0775908>)

# %%
plot_surface('kr-rand', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90d060a668>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90d0669b00>)

# %%
plot_surface('kr-peri', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90d0554eb8>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90d0547128>)

# %%
plot_surface('balanced-tree', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90d075d588>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90d06715c0>)
