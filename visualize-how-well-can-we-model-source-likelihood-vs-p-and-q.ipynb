# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt, cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import axes3d
from time import sleep

# %%
gtype = 'kr-hier'

# %%
def plot_surface(gtype, which, fig, angle=(15, 210)):
    X, Y, ratio_median, ratio_mean, dist_median, dist_mean = np.load(
        'figs/{}/source-likelihood-vs-p-and-q-data.npz'.format(gtype))['arr_0']    
    if which == 'ratio_median':
        Z = ratio_median
    elif which == 'ratio_mean':
        Z = ratio_mean
    elif which == 'dist_median':
        Z = dist_median
    elif which == 'dist_mean':
        Z = dist_mean
    else:
        raise ValueError('invalid data type')
        
    ax = fig.gca(projection='3d')
    surf = ax.plot_surface(X, Y, Z, 
                           rstride=1, cstride=1,
                           vmin=0, vmax=1,
                           cmap=cm.coolwarm)
    ax.set_zlim(0, Z.max())
    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
    fig.colorbar(surf, shrink=0.5, aspect=5)    

    ax.set_xlabel('q')
    ax.set_ylabel('p')
    ax.set_zlabel(which)
    ax.view_init(*angle)
    return fig, ax

# %%
fig, ax = plot_surface('barabasi', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_surface('kr-hier', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf708134a8>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf788a2ac8>)

# %%
plot_surface('kr-rand', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf707a60f0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf70fb11d0>)

# %%
plot_surface('kr-peri', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf707326a0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf707756a0>)

# %%
plot_surface('er', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf70648320>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf70968f28>)

# %%
plot_surface('pl-tree', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf705d6c88>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf705cd390>)

# %%
plot_surface('balanced-tree', 'ratio_mean', plt.figure())
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7faf7056bd68>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7faf705adba8>)
