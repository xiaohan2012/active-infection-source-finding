# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
from plot_utils import plot_source_likelihood_surface as plot_surface

# %%
graph_type = 'dist_mean'
if graph_type.startswith('dist'):
    angle = (10, 45)
else:
    angle = (15, 210)

# %%
plot_surface?

# %%
fig, ax = plot_surface('er', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface('barabasi', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_surface('kr-hier', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f8528e375f8>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f85284fa400>)

# %%
plot_surface('kr-rand', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f8528a560b8>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f8531a9f208>)

# %%
plot_surface('kr-peri', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f8528e91320>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f8528e8b2e8>)

# %%
plot_surface('pl-tree', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f852847d978>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f8528401d30>)

# %%
plot_surface('balanced-tree', graph_type, plt.figure(), angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f8528388710>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f8528e40160>)
