# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
from plot_utils import plot_source_likelihood_surface as plot_surface

# %%
graph_type = 'ratio_mean'
dirname = 'source-likelihood-drs'
param = '2-6'
if graph_type.startswith('dist'):
    angle = (10, 45)
else:
    angle = (15, 210)

# %%
fig, ax = plot_surface('balanced-tree', param, graph_type, plt.figure(), 
                       dirname='source-likelihood-drs-gt', angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface('balanced-tree', param, graph_type, plt.figure(), 
                       dirname='source-likelihood-drs', angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface('barabasi', param, graph_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_surface('kr-hier', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90cbc7c860>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90cbb30278>)

# %%
plot_surface('kr-rand', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90cbb30c88>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90cbdd6908>)

# %%
plot_surface('kr-peri', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90cbc7c898>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90cbf20dd8>)

# %%
plot_surface('balanced-tree', param, graph_type, plt.figure(), 
             dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7f90cbc7c6a0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f90cbe77b70>)
