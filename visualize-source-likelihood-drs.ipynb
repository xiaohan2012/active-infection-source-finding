# %%
# %matplotlib notebook
import os
import numpy as np
from matplotlib import pyplot as plt
from plot_utils import plot_source_likelihood_surface as plot_surface

# %%
gtype = 'barabasi'
plot_type = 'ratio_mean'
dirname = 'source-likelihood-drs'
param = '2-6'
output_dir = 'figs/source-likelihood-drs-by-ref-nodes-fraction/{}'.format(gtype)

# %%
fs = np.linspace(0.1, 0.4, 4)
data_list = [np.load('outputs/{}/{}/{}-f_ref-{:.1f}.npz'.format(dirname, gtype, param, f)) for f in fs]
X, Y = data_list[0]['arr_0'], data_list[0]['arr_1']

to_plot_data = {
'ratio_median': [d['arr_2'] for d in data_list],
'ratio_mean': [d['arr_3'] for d in data_list],
'dist_median': [d['arr_4'] for d in data_list],
'dist_mean': [d['arr_5'] for d in data_list]
}

# %%
for name, m in to_plot_data.items():
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    per_size, nrow, ncol = 5, 5, 2
    fig = plt.figure(figsize=(ncol * per_size, nrow * per_size))
    for i, p in enumerate(np.linspace(0.1, 1.0, 10)):
        ax = fig.add_subplot(nrow, ncol, i+1)
        for j, (ratio_mean, f) in enumerate(zip(ratio_means, fs)):        
            ax.plot(ratio_mean[i, :], 'o-')
        ax.legend(['f={:.1f}'.format(f) for f in fs], loc='best')
        ax.set_title('p={:.1f}'.format(p))
        ax.set_xlabel('q')
        ax.set_ylabel(name)
    fig.savefig('{}/{}-by-q.pdf'.format(output_dir, name))
    
    per_size, nrow, ncol = 5, 5, 2
    fig = plt.figure(figsize=(ncol * per_size, nrow * per_size))
    for i, q in enumerate(np.linspace(0.1, 1.0, 10)):
        ax = fig.add_subplot(nrow, ncol, i+1)
        for j, (ratio_mean, f) in enumerate(zip(ratio_means, fs)):        
            ax.plot(ratio_mean[:, i], 'o-')
        ax.legend(['f={:.1f}'.format(f) for f in fs], loc='best')
        ax.set_title('q={:.1f}'.format(q))
        ax.set_xlabel('p')
        ax.set_ylabel(name)
        fig.savefig('{}/{}-by-p.pdf'.format(output_dir, name))
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
per_size, nrow, ncol = 5, 5, 2
fig = plt.figure(figsize=(ncol * per_size, nrow * per_size))
for i, q in enumerate(np.linspace(0.1, 1.0, 10)):
    ax = fig.add_subplot(nrow, ncol, i+1)
    for j, (ratio_mean, f) in enumerate(zip(ratio_means, fs)):        
        ax.plot(ratio_mean[:, i], 'o-')
    ax.legend(['f={:.1f}'.format(f) for f in fs], loc='best')
    ax.set_title('q={:.1f}'.format(q))
    ax.set_xlabel('p')
    ax.set_ylabel('ratio mean')
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface(gtype, '2-6-f_ref-0.1', plot_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface(gtype, '2-6-f_ref-0.2', plot_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface(gtype, '2-6-f_ref-0.3', plot_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plot_surface(gtype, '2-6-f_ref-0.4', plot_type, plt.figure(), 
                       dirname=dirname, angle=angle)
# Out:
# <img src="data:image/png;base64,...">
